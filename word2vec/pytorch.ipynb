# %%
import re, string 
import torch
import pandas as pd 
from torch.autograd import Variable
import numpy as np
import torch.functional as F
import torch.nn.functional as F
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
STOPWORDS = set(stopwords.words('english'))

# %%
df = pd.read_csv('bbc-text.csv')
df.head()
# Out:
#         category                                               text
# 0           tech  tv future in the hands of viewers with home th...
# 1       business  worldcom boss  left books alone  former worldc...
# 2          sport  tigers wary of farrell  gamble  leicester say ...
# 3          sport  yeading face newcastle in fa cup premiership s...
# 4  entertainment  ocean s twelve raids box office ocean s twelve...

# %%
def clean_text(text):
    '''Make text lowercase, remove text in square brackets, remove punctuation and remove words containing numbers.'''
    text = text.lower()
    text = re.sub(r'\[.*?\]', '', text)
    text = re.sub(r'[%s]' % re.escape(string.punctuation), '', text)
    text = re.sub(r'\w*\d\w*', '', text)
    # Remove a sentence if it is only one word long
    if len(text) > 2:
        return ' '.join(word for word in text.split() if word not in STOPWORDS)

df_clean = pd.DataFrame(df.text.apply(lambda x: clean_text(x)))

# %%
df_clean.head()
# Out:
#                                                 text
# 0  tv future hands viewers home theatre systems p...
# 1  worldcom boss left books alone former worldcom...
# 2  tigers wary farrell gamble leicester say rushe...
# 3  yeading face newcastle fa cup premiership side...
# 4  ocean twelve raids box office ocean twelve cri...

# %%
clean_corpus = df_clean['text'].values.tolist()

def tokenize_corpus(corpus):
    tokens = [x.split() for x in corpus]
    return tokens

tokenized_corpus = tokenize_corpus(clean_corpus)
len(tokenized_corpus)
# Out:
# 2225

# %%
vocabulary = []
for sentence in tokenized_corpus:
    for token in sentence:
        if token not in vocabulary:
            vocabulary.append(token)

word2idx = {w: idx for (idx, w) in enumerate(vocabulary)}
idx2word = {idx: w for (idx, w) in enumerate(vocabulary)}

vocabulary_size = len(vocabulary)

# %%
word2idx
# Out:
# {'tv': 0,
#  'future': 1,
#  'hands': 2,
#  'viewers': 3,
#  'home': 4,
#  'theatre': 5,
#  'systems': 6,
#  'plasma': 7,
#  'highdefinition': 8,
#  'tvs': 9,
#  'digital': 10,
#  'video': 11,
#  'recorders': 12,
#  'moving': 13,
#  'living': 14,
#  'room': 15,
#  'way': 16,
#  'people': 17,
#  'watch': 18,
#  'radically': 19,
#  'different': 20,
#  'five': 21,
#  'years': 22,
#  'time': 23,
#  'according': 24,
#  'expert': 25,
#  'panel': 26,
#  'gathered': 27,
#  'annual': 28,
#  'consumer': 29,
#  'electronics': 30,
#  'show': 31,
#  'las': 32,
#  'vegas': 33,
#  'discuss': 34,
#  'new': 35,
#  'technologies': 36,
#  'impact': 37,
#  'one': 38,
#  'favourite': 39,
#  'pastimes': 40,
#  'us': 41,
#  'leading': 42,
#  'trend': 43,
#  'programmes': 44,
#  'content': 45,
#  'delivered': 46,
#  'via': 47,
#  'networks': 48,
#  'cable': 49,
#  'satellite': 50,
#  'telecoms': 51,
#  'companies': 52,
#  'broadband': 53,
#  'service': 54,
#  'providers': 55,
#  'front': 56,
#  'rooms': 57,
#  'portable': 58,
#  'devices': 59,
#  'talkedabout': 60,
#  'ces': 61,
#  'personal': 62,
#  'dvr': 63,
#  'pvr': 64,
#  'settop': 65,
#  'boxes': 66,
#  'like': 67,
#  'tivo': 68,
#  'uk': 69,
#  'sky': 70,
#  'system': 71,
#  'allow': 72,
#  'record': 73,
#  'store': 74,
#  'play': 75,
#  'pause': 76,
#  'forward': 77,
#  'wind': 78,
#  'want': 79,
#  'essentially': 80,
#  'technology': 81,
#  'allows': 82,
#  'much': 83,
#  'personalised': 84,
#  'also': 85,
#  'builtin': 86,
#  'sets': 87,
#  'big': 88,
#  'business': 89,
#  'japan': 90,
#  'slower': 91,
#  'take': 92,
#  'europe': 93,
#  'lack': 94,
#  'programming': 95,
#  'adverts': 96,
#  'forget': 97,
#  'abiding': 98,
#  'network': 99,
#  'channel': 100,
#  'schedules': 101,
#  'putting': 102,
#  'together': 103,
#  'alacarte': 104,
#  'entertainment': 105,
#  'worried': 106,
#  'means': 107,
#  'terms': 108,
#  'advertising': 109,
#  'revenues': 110,
#  'well': 111,
#  'brand': 112,
#  'identity': 113,
#  'viewer': 114,
#  'loyalty': 115,
#  'channels': 116,
#  'although': 117,
#  'leads': 118,
#  'moment': 119,
#  'concern': 120,
#  'raised': 121,
#  'particularly': 122,
#  'growing': 123,
#  'uptake': 124,
#  'services': 125,
#  'happens': 126,
#  'today': 127,
#  'see': 128,
#  'nine': 129,
#  'months': 130,
#  'adam': 131,
#  'hume': 132,
#  'bbc': 133,
#  'broadcast': 134,
#  'futurologist': 135,
#  'told': 136,
#  'news': 137,
#  'website': 138,
#  'likes': 139,
#  'issues': 140,
#  'lost': 141,
#  'revenue': 142,
#  'yet': 143,
#  'pressing': 144,
#  'issue': 145,
#  'commercial': 146,
#  'broadcasters': 147,
#  'important': 148,
#  'everyone': 149,
#  'talking': 150,
#  'brands': 151,
#  'rather': 152,
#  'said': 153,
#  'tim': 154,
#  'hanlon': 155,
#  'communications': 156,
#  'firm': 157,
#  'starcom': 158,
#  'mediavest': 159,
#  'reality': 160,
#  'connections': 161,
#  'anybody': 162,
#  'producer': 163,
#  'added': 164,
#  'challenge': 165,
#  'hard': 166,
#  'promote': 167,
#  'programme': 168,
#  'choice': 169,
#  'stacey': 170,
#  'jolna': 171,
#  'senior': 172,
#  'vice': 173,
#  'president': 174,
#  'guide': 175,
#  'group': 176,
#  'find': 177,
#  'simplified': 178,
#  'could': 179,
#  'leaf': 180,
#  'google': 181,
#  'book': 182,
#  'search': 183,
#  'engine': 184,
#  'instead': 185,
#  'scheduler': 186,
#  'help': 187,
#  'kind': 188,
#  'model': 189,
#  'might': 190,
#  'work': 191,
#  'younger': 192,
#  'ipod': 193,
#  'generation': 194,
#  'used': 195,
#  'taking': 196,
#  'control': 197,
#  'gadgets': 198,
#  'suit': 199,
#  'recognised': 200,
#  'older': 201,
#  'generations': 202,
#  'comfortable': 203,
#  'familiar': 204,
#  'know': 205,
#  'getting': 206,
#  'perhaps': 207,
#  'put': 208,
#  'mr': 209,
#  'suggested': 210,
#  'end': 211,
#  'kids': 212,
#  'diapers': 213,
#  'pushing': 214,
#  'buttons': 215,
#  'already': 216,
#  'everything': 217,
#  'possible': 218,
#  'available': 219,
#  'ultimately': 220,
#  'tell': 221,
#  'market': 222,
#  'showcased': 223,
#  'many': 224,
#  'enhancing': 225,
#  'tvwatching': 226,
#  'experience': 227,
#  'everywhere': 228,
#  'models': 229,
#  'lcd': 230,
#  'liquid': 231,
#  'crystal': 232,
#  'display': 233,
#  'launched': 234,
#  'capability': 235,
#  'built': 236,
#  'external': 237,
#  'example': 238,
#  'humax': 239,
#  'dvd': 240,
#  'recorder': 241,
#  'biggest': 242,
#  'directtv': 243,
#  'even': 244,
#  'branded': 245,
#  'recording': 246,
#  'instant': 247,
#  'replay': 248,
#  'function': 249,
#  'set': 250,
#  'rewind': 251,
#  'hours': 252,
#  'microsoft': 253,
#  'chief': 254,
#  'bill': 255,
#  'gates': 256,
#  'announced': 257,
#  'preshow': 258,
#  'keynote': 259,
#  'speech': 260,
#  'partnership': 261,
#  'called': 262,
#  'tivotogo': 263,
#  'recorded': 264,
#  'windows': 265,
#  'pcs': 266,
#  'mobile': 267,
#  'reflect': 268,
#  'increasing': 269,
#  'freeing': 270,
#  'multimedia': 271,
#  'worldcom': 272,
#  'boss': 273,
#  'left': 274,
#  'books': 275,
#  'alone': 276,
#  'former': 277,
#  'bernie': 278,
#  'ebbers': 279,
#  'accused': 280,
#  'overseeing': 281,
#  '£': 282,
#  'fraud': 283,
#  'never': 284,
#  'made': 285,
#  'accounting': 286,
#  'decisions': 287,
#  'witness': 288,
#  'jurors': 289,
#  'david': 290,
#  'myers': 291,
#  'comments': 292,
#  'questioning': 293,
#  'defence': 294,
#  'lawyers': 295,
#  'arguing': 296,
#  'responsible': 297,
#  'problems': 298,
#  'phone': 299,
#  'company': 300,
#  'collapsed': 301,
#  'prosecutors': 302,
#  'claim': 303,
#  'losses': 304,
#  'hidden': 305,
#  'protect': 306,
#  'shares': 307,
#  'pleaded': 308,
#  'guilty': 309,
#  'assisting': 310,
#  'monday': 311,
#  'lawyer': 312,
#  'reid': 313,
#  'weingarten': 314,
#  'tried': 315,
#  'distance': 316,
#  'client': 317,
#  'allegations': 318,
#  'cross': 319,
#  'examination': 320,
#  'asked': 321,
#  'ever': 322,
#  'knew': 323,
#  'make': 324,
#  'decision': 325,
#  'aware': 326,
#  'replied': 327,
#  'entry': 328,
#  'pressed': 329,
#  'admitted': 330,
#  'ordered': 331,
#  'false': 332,
#  'entries': 333,
#  'request': 334,
#  'financial': 335,
#  'officer': 336,
#  'scott': 337,
#  'sullivan': 338,
#  'trying': 339,
#  'paint': 340,
#  'testify': 341,
#  'later': 342,
#  'trial': 343,
#  'mastermind': 344,
#  'behind': 345,
#  'house': 346,
#  'cards': 347,
#  'team': 348,
#  'meanwhile': 349,
#  'looking': 350,
#  'portray': 351,
#  'affable': 352,
#  'admission': 353,
#  'pe': 354,
#  'graduate': 355,
#  'economist': 356,
#  'whatever': 357,
#  'abilities': 358,
#  'transformed': 359,
#  'relative': 360,
#  'unknown': 361,
#  'giant': 362,
#  'investor': 363,
#  'darling': 364,
#  'late': 365,
#  'mounted': 366,
#  'however': 367,
#  'competition': 368,
#  'increased': 369,
#  'boom': 370,
#  'petered': 371,
#  'finally': 372,
#  'shareholders': 373,
#  'workers': 374,
#  'jobs': 375,
#  'expected': 376,
#  'last': 377,
#  'two': 378,
#  'found': 379,
#  'ceo': 380,
#  'faces': 381,
#  'substantial': 382,
#  'jail': 383,
#  'sentence': 384,
#  'firmly': 385,
#  'declared': 386,
#  'innocence': 387,
#  'tigers': 388,
#  'wary': 389,
#  'farrell': 390,
#  'gamble': 391,
#  'leicester': 392,
#  'say': 393,
#  'rushed': 394,
#  'making': 395,
#  'bid': 396,
#  'andy': 397,
#  'great': 398,
#  'britain': 399,
#  'rugby': 400,
#  'league': 401,
#  'captain': 402,
#  'decide': 403,
#  'switch': 404,
#  'codes': 405,
#  'else': 406,
#  'involved': 407,
#  'process': 408,
#  'still': 409,
#  'away': 410,
#  'going': 411,
#  'next': 412,
#  'stage': 413,
#  'john': 414,
#  'wells': 415,
#  'radio': 416,
#  'lot': 417,
#  'unknowns': 418,
#  'least': 419,
#  'medical': 420,
#  'situation': 421,
#  'whoever': 422,
#  'persistent': 423,
#  'knee': 424,
#  'operation': 425,
#  'weeks': 426,
#  'ago': 427,
#  'another': 428,
#  'three': 429,
#  'saracens': 430,
#  'believed': 431,
#  'head': 432,
#  'list': 433,
#  'union': 434,
#  'clubs': 435,
#  'interested': 436,
#  'signing': 437,
#  'decides': 438,
#  'move': 439,
#  'game': 440,
#  'across': 441,
#  'believes': 442,
#  'would': 443,
#  'better': 444,
#  'playing': 445,
#  'backs': 446,
#  'initially': 447,
#  'sure': 448,
#  'step': 449,
#  'centre': 450,
#  'think': 451,
#  'england': 452,
#  'prefer': 453,
#  'progress': 454,
#  'position': 455,
#  'back': 456,
#  'row': 457,
#  'use': 458,
#  'skills': 459,
#  'within': 460,
#  'forwards': 461,
#  'jury': 462,
#  'whether': 463,
#  'divide': 464,
#  'club': 465,
#  'balance': 466,
#  'struck': 467,
#  'cost': 468,
#  'option': 469,
#  'bringing': 470,
#  'readymade': 471,
#  'replacement': 472,
#  'yeading': 473,
#  'face': 474,
#  'newcastle': 475,
#  'fa': 476,
#  'cup': 477,
#  'premiership': 478,
#  'side': 479,
#  'united': 480,
#  'trip': 481,
#  'ryman': 482,
#  'premier': 483,
#  'leaders': 484,
#  'third': 485,
#  'round': 486,
#  'arguably': 487,
#  'highlight': 488,
#  'draw': 489,
#  'potential': 490,
#  'moneyspinner': 491,
#  'nonleague': 492,
#  'beat': 493,
#  'slough': 494,
#  'second': 495,
#  'conference': 496,
#  'exeter': 497,
#  'city': 498,
#  'knocked': 499,
#  'doncaster': 500,
#  'saturday': 501,
#  'travel': 502,
#  'old': 503,
#  'trafford': 504,
#  'meet': 505,
#  'holders': 506,
#  'manchester': 507,
#  'january': 508,
#  'arsenal': 509,
#  'drawn': 510,
#  'stoke': 511,
#  'chelsea': 512,
#  'host': 513,
#  'scunthorpe': 514,
#  'hinckley': 515,
#  'held': 516,
#  'brentford': 517,
#  'goalless': 518,
#  'sunday': 519,
#  'luton': 520,
#  'win': 521,
#  'martin': 522,
#  'allen': 523,
#  'griffin': 524,
#  'park': 525,
#  'number': 526,
#  'teams': 527,
#  'difficult': 528,
#  'games': 529,
#  'championship': 530,
#  'sides': 531,
#  'weekend': 532,
#  'thirdplaced': 533,
#  'everton': 534,
#  'visit': 535,
#  'plymouth': 536,
#  'liverpool': 537,
#  'burnley': 538,
#  'palace': 539,
#  'go': 540,
#  'sunderland': 541,
#  'fulham': 542,
#  'carling': 543,
#  'semifinalists': 544,
#  'watford': 545,
#  'bolton': 546,
#  'ipswich': 547,
#  'aston': 548,
#  'villa': 549,
#  'sheffield': 550,
#  'strugglers': 551,
#  'norwich': 552,
#  'blackburn': 553,
#  'west': 554,
#  'brom': 555,
#  'ham': 556,
#  'cardiff': 557,
#  'preston': 558,
#  'north': 559,
#  'respectively': 560,
#  'southampton': 561,
#  'northampton': 562,
#  'beaten': 563,
#  'earlier': 564,
#  'season': 565,
#  'middlesbrough': 566,
#  'either': 567,
#  'swindon': 568,
#  'notts': 569,
#  'county': 570,
#  'spurs': 571,
#  'entertain': 572,
#  'brighton': 573,
#  'white': 574,
#  'hart': 575,
#  'lane': 576,
#  'v': 577,
#  'swindonnotts': 578,
#  'co': 579,
#  'man': 580,
#  'utd': 581,
#  'blackpool': 582,
#  'derby': 583,
#  'wigan': 584,
#  'wolves': 585,
#  'millwall': 586,
#  'hull': 587,
#  'colchester': 588,
#  'tottenham': 589,
#  'reading': 590,
#  'stockportswansea': 591,
#  'birmingham': 592,
#  'leeds': 593,
#  'hartlepool': 594,
#  'boston': 595,
#  'milton': 596,
#  'keynes': 597,
#  'dons': 598,
#  'peterborough': 599,
#  'oldham': 600,
#  'charlton': 601,
#  'rochdale': 602,
#  'sheff': 603,
#  'rotherham': 604,
#  'yeovil': 605,
#  'bournemouth': 606,
#  'chester': 607,
#  'coventry': 608,
#  'crewe': 609,
#  'portsmouth': 610,
#  'gillingham': 611,
#  'qpr': 612,
#  'nottm': 613,
#  'forest': 614,
#  'hinckleybrentford': 615,
#  'matches': 616,
#  'played': 617,
#  'ocean': 618,
#  'twelve': 619,
#  'raids': 620,
#  'box': 621,
#  'office': 622,
#  'crime': 623,
#  'caper': 624,
#  'sequel': 625,
#  'starring': 626,
#  'george': 627,
#  'clooney': 628,
#  'brad': 629,
#  'pitt': 630,
#  'julia': 631,
#  'roberts': 632,
#  'gone': 633,
#  'straight': 634,
#  'chart': 635,
#  'took': 636,
#  'ticket': 637,
#  'sales': 638,
#  'studio': 639,
#  'estimates': 640,
#  'follows': 641,
#  'master': 642,
#  'criminals': 643,
#  'try': 644,
#  'pull': 645,
#  'major': 646,
#  'heists': 647,
#  'week': 648,
#  'national': 649,
#  'treasure': 650,
#  'place': 651,
#  'wesley': 652,
#  'snipes': 653,
#  'blade': 654,
#  'trinity': 655,
#  'rounding': 656,
#  'top': 657,
#  'animated': 658,
#  'fable': 659,
#  'polar': 660,
#  'express': 661,
#  'tom': 662,
#  'hanks': 663,
#  'festive': 664,
#  'comedy': 665,
#  'christmas': 666,
#  'kranks': 667,
#  'triumph': 668,
#  'marks': 669,
#  'fourthbiggest': 670,
#  'opening': 671,
#  'december': 672,
#  'release': 673,
#  'films': 674,
#  'lord': 675,
#  'rings': 676,
#  'trilogy': 677,
#  'narrowly': 678,
#  'predecessor': 679,
#  'eleven': 680,
#  'total': 681,
#  'remake': 682,
#  'film': 683,
#  'frank': 684,
#  'sinatra': 685,
#  'rat': 686,
#  'pack': 687,
#  'directed': 688,
#  'oscarwinning': 689,
#  'director': 690,
#  'steven': 691,
#  'soderbergh': 692,
#  'returns': 693,
#  'direct': 694,
#  'hit': 695,
#  'reunites': 696,
#  'matt': 697,
#  'damon': 698,
#  'garcia': 699,
#  'elliott': 700,
#  'gould': 701,
#  'catherine': 702,
#  'zetajones': 703,
#  'joins': 704,
#  'allstar': 705,
#  'cast': 706,
#  'fun': 707,
#  'good': 708,
#  'holiday': 709,
#  'movie': 710,
#  'dan': 711,
#  'fellman': 712,
#  'distribution': 713,
#  'warner': 714,
#  'bros': 715,
#  'critics': 716,
#  'less': 717,
#  'complimentary': 718,
#  'project': 719,
#  'los': 720,
#  'angeles': 721,
#  'times': 722,
#  'labelling': 723,
#  'dispiriting': 724,
#  'vanity': 725,
#  'milder': 726,
#  'review': 727,
#  'york': 728,
#  'dubbed': 729,
#  'unabashedly': 730,
#  'trivial': 731,
#  'howard': 732,
#  'hits': 733,
#  'mongrel': 734,
#  'jibe': 735,
#  'michael': 736,
#  'peter': 737,
#  'hain': 738,
#  'tory': 739,
#  'leader': 740,
#  'acting': 741,
#  'attack': 742,
#  'shows': 743,
#  'labour': 744,
#  'rattled': 745,
#  'opposition': 746,
#  'upbeat': 747,
#  'party': 748,
#  'spring': 749,
#  'campaigning': 750,
#  'tactics': 751,
#  'proved': 752,
#  'tories': 753,
#  'hitting': 754,
#  'antiterror': 755,
#  'debate': 756,
#  'something': 757,
#  'tells': 758,
#  'someone': 759,
#  'somewhere': 760,
#  'little': 761,
#  'bit': 762,
#  'commons': 763,
#  'four': 764,
#  'stance': 765,
#  'government': 766,
#  'antiterrorism': 767,
#  'legislation': 768,
#  'country': 769,
#  'risk': 770,
#  'behaving': 771,
#  'sake': 772,
#  'anything': 773,
#  'cling': 774,
#  'costs': 775,
#  'far': 776,
#  'year': 777,
#  'compared': 778,
#  'fagin': 779,
#  'shylock': 780,
#  'flying': 781,
#  'pig': 782,
#  'morning': 783,
#  'environment': 784,
#  'secretary': 785,
#  'margaret': 786,
#  'beckett': 787,
#  'rejected': 788,
#  'comment': 789,
#  'telling': 790,
#  'pm': 791,
#  'real': 792,
#  'duty': 793,
#  'get': 794,
#  'focus': 795,
#  'proposals': 796,
#  'examples': 797,
#  'seeing': 798,
#  'believe': 799,
#  'really': 800,
#  'poor': 801,
#  'judgement': 802,
#  'behalf': 803,
#  'policies': 804,
#  'schools': 805,
#  'taxes': 806,
#  'immigration': 807,
#  'striking': 808,
#  'chord': 809,
#  'voters': 810,
#  'since': 811,
#  'beginning': 812,
#  'election': 813,
#  'political': 814,
#  'weather': 815,
#  'denied': 816,
#  'politics': 817,
#  'raising': 818,
#  'case': 819,
#  'dixon': 820,
#  'whose': 821,
#  'cancelled': 822,
#  'seven': 823,
#  'grabbed': 824,
#  'headlines': 825,
#  'claims': 826,
#  'mrs': 827,
#  'human': 828,
#  'shield': 829,
#  'blair': 830,
#  'plans': 831,
#  'quotas': 832,
#  'media': 833,
#  'coverage': 834,
#  'racist': 835,
#  'common': 836,
#  'sense': 837,
#  'pledged': 838,
#  'cleaner': 839,
#  'hospitals': 840,
#  'school': 841,
#  'discipline': 842,
#  'promise': 843,
#  'rid': 844,
#  'correctness': 845,
#  'curriculum': 846,
#  'give': 847,
#  'chance': 848,
#  'decent': 849,
#  'state': 850,
#  'education': 851,
#  'come': 852,
#  'ordinary': 853,
#  'family': 854,
#  'teenage': 855,
#  'applying': 856,
#  'cambridge': 857,
#  'gordon': 858,
#  'brown': 859,
#  'love': 860,
#  'stressed': 861,
#  'commitment': 862,
#  'cut': 863,
#  'red': 864,
#  'tape': 865,
#  'increase': 866,
#  'basic': 867,
#  'pension': 868,
#  'line': 869,
#  'earnings': 870,
#  'finished': 871,
#  'appeal': 872,
#  'activists': 873,
#  'day': 874,
#  'able': 875,
#  'children': 876,
#  'grandchildren': 877,
#  'mine': 878,
#  'part': 879,
#  'helped': 880,
#  'famous': 881,
#  'coordinator': 882,
#  'alan': 883,
#  'milburn': 884,
#  'confirms': 885,
#  'always': 886,
#  'strategy': 887,
#  'opportunism': 888,
#  'vision': 889,
#  'reference': 890,
#  'appearance': 891,
#  'perfectly': 892,
#  'entitled': 893,
#  'pose': 894,
#  'working': 895,
#  'families': 896,
#  'damaged': 897,
#  'plan': 898,
#  'public': 899,
#  'spending': 900,
#  'prepares': 901,
#  'name': 902,
#  'poll': 903,
#  'date': 904,
#  'tony': 905,
#  'likely': 906,
#  'may': 907,
#  'parliament': 908,
#  'easter': 909,
#  'break': 910,
#  'editor': 911,
#  'learned': 912,
#  'andrew': 913,
#  'marr': 914,
#  'says': 915,
#  'ask': 916,
#  'queen': 917,
#  'april': 918,
#  'dissolve': 919,
#  'resisted': 920,
#  'calls': 921,
#  'parties': 922,
#  'stepped': 923,
#  'recently': 924,
#  'downing': 925,
#  'street': 926,
#  'saying': 927,
#  'timing': 928,
#  'matter': 929,
#  'prime': 930,
#  'minister': 931,
#  'spokeswoman': 932,
#  'announce': 933,
#  'wants': 934,
#  'signal': 935,
#  'frantic': 936,
#  'westminster': 937,
#  'key': 938,
#  'needs': 939,
#  'finance': 940,
#  'covering': 941,
#  'budget': 942,
#  'passed': 943,
#  'closes': 944,
#  'session': 945,
#  'seek': 946,
#  'push': 947,
#  'serious': 948,
#  'organised': 949,
#  'id': 950,
#  'wednesday': 951,
#  'almost': 952,
#  'nobody': 953,
#  'level': 954,
#  'inside': 955,
#  'expect': 956,
#  'soon': 957,
#  'short': 958,
#  'recess': 959,
#  'whips': 960,
#  'asks': 961,
#  'officially': 962,
#  'june': 963,
#  'hold': 964,
#  'general': 965,
#  'recent': 966,
#  'governments': 967,
#  'favoured': 968,
#  'fouryear': 969,
#  'henman': 970,
#  'hopes': 971,
#  'ended': 972,
#  'dubai': 973,
#  'seed': 974,
#  'slumped': 975,
#  'defeat': 976,
#  'raininterrupted': 977,
#  'open': 978,
#  'quarterfinal': 979,
#  'ivan': 980,
#  'ljubicic': 981,
#  'croatian': 982,
#  'eighth': 983,
#  'booked': 984,
#  'victory': 985,
#  'british': 986,
#  'looked': 987,
#  'course': 988,
#  'match': 989,
#  'halted': 990,
#  'rain': 991,
#  'intervened': 992,
#  'seal': 993,
#  'fourth': 994,
#  'spanish': 995,
#  'fifth': 996,
#  'tommy': 997,
#  'robredo': 998,
#  'secured': 999,
#  ...}

# %%
window_size = 2
idx_pairs = []
# for each sentence
for sentence in tokenized_corpus:
    indices = [word2idx[word] for word in sentence]
    # for each word, threated as center word
    for center_word_pos in range(len(indices)):
        # for each window position
        for w in range(-window_size, window_size + 1):
            context_word_pos = center_word_pos + w
            # make soure not jump out sentence
            if context_word_pos < 0 or context_word_pos >= len(indices) or center_word_pos == context_word_pos:
                continue
            context_word_idx = indices[context_word_pos]
            idx_pairs.append((indices[center_word_pos], context_word_idx))

idx_pairs = np.array(idx_pairs) # it will be useful to have this as numpy array

# %%
idx_pairs[:10]
# Out:
# array([[0, 1],
#        [0, 2],
#        [1, 0],
#        [1, 2],
#        [1, 3],
#        [2, 0],
#        [2, 1],
#        [2, 3],
#        [2, 4],
#        [3, 1]])

# %%
def get_input_layer(word_idx):
    x = torch.zeros(vocabulary_size).float()
    x[word_idx] = 1.0
    return x
  
  #Input layer is just the center word encoded in one-hot manner. It dimensions are [1, vocabulary_size]

# %%
embedding_dims = 5
W1 = Variable(torch.randn(embedding_dims, vocabulary_size).float(), requires_grad=True)
W2 = Variable(torch.randn(vocabulary_size, embedding_dims).float(), requires_grad=True)
num_epochs = 101
learning_rate = 0.001

for epo in range(num_epochs):
    loss_val = 0
    for data, target in idx_pairs:
        x = Variable(get_input_layer(data)).float()
        y_true = Variable(torch.from_numpy(np.array([target])).long())

        z1 = torch.matmul(W1, x)
        z2 = torch.matmul(W2, z1)
    
        log_softmax = F.log_softmax(z2, dim=0)

        loss = F.nll_loss(log_softmax.view(1,-1), y_true)
        loss_val += loss.data.item()
        loss.backward()
        W1.data -= learning_rate * W1.grad.data
        W2.data -= learning_rate * W2.grad.data

        W1.grad.data.zero_()
        W2.grad.data.zero_()
    if epo % 10 == 0:    
        print(f'Loss at epo {epo}: {loss_val/len(idx_pairs)}')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-15fe006a74b6> in <module>
#      18         loss = F.nll_loss(log_softmax.view(1,-1), y_true)
#      19         loss_val += loss.data.item()
# ---> 20         loss.backward()
#      21         W1.data -= learning_rate * W1.grad.data
#      22         W2.data -= learning_rate * W2.grad.data
#
# C:\Users\builder\Anaconda\lib\site-packages\torch\tensor.py in backward(self, gradient, retain_graph, create_graph)
#     193                 products. Defaults to ``False``.
#     194         """
# --> 195         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     196
#     197     def register_hook(self, hook):
#
# C:\Users\builder\Anaconda\lib\site-packages\torch\autograd\__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#      97     Variable._execution_engine.run_backward(
#      98         tensors, grad_tensors, retain_graph, create_graph,
# ---> 99         allow_unreachable=True)  # allow_unreachable flag
#     100
#     101
#
# KeyboardInterrupt:
